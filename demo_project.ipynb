# %%
#import library
import project as ml

# %%
#Returns all types of ODE names
print("Kinds:", ml.list_kinds())

#Returns topic (for future additions I want to add)
print("Topics:", ml.list_topics())

#Retuns all "commands" for the user
ml.help()

# %%
#For problem sheets you want to save as a PDF you should specify where it should go in the ""
#(else defaults to this directory)
saveto = r"C:\Users\james\OneDrive\Desktop\Computing_project_videos\demo_folder"

#Creates problem sheet with params: n (number of questions), kind (style of differential equations),
#difficulty (self explanitory), export=True/False (Depending on if you want it exported), saveto= (path to save pdf to)
ml.problem_sheet(n=20, kind="mixed", difficulty="mixed", export=True, saveto=saveto);

# %%
#Generates a random ODE problem with params of kind and whether you want initial conditions
example_question = ml.generate(kind="mixed", with_ics=True)
example_question
# Out:
# $- 6 y + \frac{dy}{dx} + \frac{d^{2}y}{dx^{2}} = 0, \quad y(0) = -2, \; y'(0) = 3$

# %%
#Solves an ODE problem (that you generated and defined) step by step using module lecture notes method
result = ml.solve(example_question)

result.show_steps()

result.verified
# Out:
# **Identify standard form**
# $\displaystyle 1 \frac{d^2 y}{dx^2} + \left(1\right) \frac{dy}{dx} + \left(-6\right) y = 0$
# *$a = 1, \; b = 1, \; c = -6$*
# **make auxiliary equation**
# $\displaystyle \mu^{2} + \mu - 6 = 0$
# *Roots: $-3, \; 2$*
# **Two distinct real roots**
# $\displaystyle \mu_1 = -3, \quad \mu_2 = 2$
# *$y = A e^{-3 x} + B e^{2 x}$*
# **General solution**
# $\displaystyle y = A e^{- 3 x} + B e^{2 x}$
# *General solution with two constants*
# **Apply initial conditions**
# $\displaystyle y(0) = -2, \quad y'(0) = 3$
# *$A = - \frac{7}{5}, \; B = - \frac{3}{5}$*
# **Particular solution**
# $\displaystyle y = \frac{\left(- 3 e^{5 x} - 7\right) e^{- 3 x}}{5}$
# **Maximal domain**
# $\displaystyle \text{Domain: } \mathbb{R}$
# *Where the solution is defined*
# True

# %%
ml.launch_web()
# Out:
# Server running http://127.0.0.1:8080
